# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# need to fix up stuff in the later cells

# %% [markdown]
# Importing the Dataframe

# %%
# Remember that double backslashes are required on pc
# Remember to input file path as a 'string'

unidata = pd.read_csv('C:\\Users\\Rose\\Desktop\\JupyterStuff\\universities.csv')

# %%
unidata.head()
# Out:
#                                       name  \
# 0  A T Still University of Health Sciences
# 1             Abilene Christian University
# 2     Abraham Baldwin Agricultural College
# 3                          Academy College
# 4     Academy for Five Element Acupuncture
#
#                                              address                 Website  \
# 0        800 W Jefferson, Kirksville, Missouri 63501            WWW.ATSU.EDU
# 1            1600 Campus Court, Abilene, Texas 79699             www.acu.edu
# 2         2802 Moore Hwy, Tifton, Georgia 31793-2601            www.abac.edu
# 3  1101 E. 78th Street, Suite 100, Minneapolis, M...  www.academycollege.edu
# 4         305 SE 2nd Ave, Gainesville, Florida 32601   www.acupuncturist.edu
#
#                                                 Type    Size
# 0                     4-year, Private not-for-profit  3480.0
# 1                     4-year, Private not-for-profit  4669.0
# ...

# %%
unidata
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
unidata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2907 non-null   object
#  1   address  2907 non-null   object
#  2   Website  2822 non-null   object
#  3   Type     2907 non-null   object
#  4   Size     2829 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 113.7+ KB

# %%
unidata.describe
# Out:
# <bound method NDFrame.describe of                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# ...

# %%
unidata.index
# Out:
# RangeIndex(start=0, stop=2907, step=1)

# %%
unidata.columns
# Out:
# Index(['name', 'address', 'Website', 'Type', 'Size'], dtype='object')

# %%
unidata.dtypes
# Out:
# name        object
# address     object
# Website     object
# Type        object
# Size       float64
# dtype: object

# %%
unidata['Type']
# Out:
# 0                          4-year, Private not-for-profit
# 1                          4-year, Private not-for-profit
# 2                   4-year, primarily associate's, Public
# 3       4-year, primarily associate's, Private for-profit
# 4                          4-year, Private not-for-profit
#                               ...
# 2902                       4-year, Private not-for-profit
# 2903                       4-year, Private not-for-profit
# 2904                       4-year, Private not-for-profit
# 2905                                       4-year, Public
# 2906                       4-year, Private not-for-profit
# Name: Type, Length: 2907, dtype: object

# %%
unidata.sort_values('Type')
# Out:
#                                                 name  \
# 2587          University of Phoenix-San Diego Campus
# 2592  University of Phoenix-Southern Colorado Campus
# 2593       University of Phoenix-Springfield  Campus
# 2594           University of Phoenix-St Louis Campus
# 2595              University of Phoenix-Tulsa Campus
# ...                                              ...
# 2785         West Virginia University at Parkersburg
# 2006                            Sitting Bull College
# 212                                 Bellevue College
# 586         CUNY New York City College of Technology
# 984                       Indian River State College
#
#                                                 address  \
# 2587  3890 Murphy Canyon Road Suite 100, San Diego, ...
# 2592  5725 Mark Dabling Blvd., Colorado Springs, Col...
# 2593  1343 E. Kingsley Street, Springfield, Missouri...
# 2594  13801 Riverport Drive, Ste. 102, Saint Louis, ...
# ...

# %% [markdown]
# Using pandas, find both the mean and median size by each university type (as given in the dataframe), ordered by average size in ascending order.

# %%
unidata.groupby("Type").aggregate([np.mean, np.median]).sort_values(by=('Size', 'mean'))
# Out:
#                                                             Size
#                                                             mean  median
# Type
# 4-year, primarily associate's, Private for-profit     934.380597   564.5
# 4-year, primarily associate's, Private not-for-...   1129.413793   768.0
# 4-year, Private not-for-profit                       2399.885696  1206.0
# 4-year, Private for-profit                           3504.501859   730.0
# 4-year, primarily associate's, Public                6889.366197  3558.0
# 4-year, Public                                      11478.913765  7669.0

# %% [markdown]
# Make new columns  in the dataframe from existing data for the following attributes:
# City
# State
# ZipCode
# Private or Public
# for-profit or not-for-profit
# primarily associate's (1 for Yes, 0 for No)
#  Using the new columns you've made above (and excluding the original type column), find both the mean and median size of each university by State, by Private or Public, and by whether the university is primarily associate's or not.

# %%
# Making a copy of the dataframe.
df = unidata.copy()

# %%
df.head(10)
# Out:
#                                                 name  \
# 0            A T Still University of Health Sciences
# 1                       Abilene Christian University
# 2               Abraham Baldwin Agricultural College
# 3                                    Academy College
# 4               Academy for Five Element Acupuncture
# 5                          Academy of Art University
# 6     Academy of Chinese Culture and Health Sciences
# 7                       Academy of Oriental Medicine
# 8                              Academy of Vocal Arts
# 9  Acupuncture and Integrative Medicine College-B...
#
#                                              address                 Website  \
# 0        800 W Jefferson, Kirksville, Missouri 63501            WWW.ATSU.EDU
# 1            1600 Campus Court, Abilene, Texas 79699             www.acu.edu
# 2         2802 Moore Hwy, Tifton, Georgia 31793-2601            www.abac.edu
# ...

# %%
df[['street', 'city', "state"]] = df['address'].str.rsplit(",",2, expand=True)

# %%
df.head(10)
# Out:
#                                                 name  \
# 0            A T Still University of Health Sciences
# 1                       Abilene Christian University
# 2               Abraham Baldwin Agricultural College
# 3                                    Academy College
# 4               Academy for Five Element Acupuncture
# 5                          Academy of Art University
# 6     Academy of Chinese Culture and Health Sciences
# 7                       Academy of Oriental Medicine
# 8                              Academy of Vocal Arts
# 9  Acupuncture and Integrative Medicine College-B...
#
#                                              address                 Website  \
# 0        800 W Jefferson, Kirksville, Missouri 63501            WWW.ATSU.EDU
# 1            1600 Campus Court, Abilene, Texas 79699             www.acu.edu
# 2         2802 Moore Hwy, Tifton, Georgia 31793-2601            www.abac.edu
# ...

# %%
df.head(10)
# Out:
#                                                 name  \
# 0            A T Still University of Health Sciences
# 1                       Abilene Christian University
# 2               Abraham Baldwin Agricultural College
# 3                                    Academy College
# 4               Academy for Five Element Acupuncture
# 5                          Academy of Art University
# 6     Academy of Chinese Culture and Health Sciences
# 7                       Academy of Oriental Medicine
# 8                              Academy of Vocal Arts
# 9  Acupuncture and Integrative Medicine College-B...
#
#                                              address                 Website  \
# 0        800 W Jefferson, Kirksville, Missouri 63501            WWW.ATSU.EDU
# 1            1600 Campus Court, Abilene, Texas 79699             www.acu.edu
# 2         2802 Moore Hwy, Tifton, Georgia 31793-2601            www.abac.edu
# ...

# %%
df.drop('state', axis=1, inplace=True)

# %%
df.head(10)
# Out:
#                                                 name  \
# 0            A T Still University of Health Sciences
# 1                       Abilene Christian University
# 2               Abraham Baldwin Agricultural College
# 3                                    Academy College
# 4               Academy for Five Element Acupuncture
# 5                          Academy of Art University
# 6     Academy of Chinese Culture and Health Sciences
# 7                       Academy of Oriental Medicine
# 8                              Academy of Vocal Arts
# 9  Acupuncture and Integrative Medicine College-B...
#
#                                              address                 Website  \
# 0        800 W Jefferson, Kirksville, Missouri 63501            WWW.ATSU.EDU
# 1            1600 Campus Court, Abilene, Texas 79699             www.acu.edu
# 2         2802 Moore Hwy, Tifton, Georgia 31793-2601            www.abac.edu
# ...

# %%
df.groupby("Type").aggregate([np.mean, np.median]).sort_values(by=('Size', 'mean'))
# Out:
#                                                             Size
#                                                             mean  median
# Type
# 4-year, primarily associate's, Private for-profit     934.380597   564.5
# 4-year, primarily associate's, Private not-for-...   1129.413793   768.0
# 4-year, Private not-for-profit                       2399.885696  1206.0
# 4-year, Private for-profit                           3504.501859   730.0
# 4-year, primarily associate's, Public                6889.366197  3558.0
# 4-year, Public                                      11478.913765  7669.0

# %%
df.to_csv('uni',index=False)
